# %% [markdown]
# Day 1

# %%
45+56
# Out:
# 101

# %%
a=4

# %%
print('Hello Coders')
# Out:
# Hello Coders

# %%
print(4)
# Out:
# 4

# %%
b = 'hello dear coders 56'

# %%
b
# Out:
# 'hello dear coders 56'

# %%
print (b)
# Out:
# hello dear coders 56

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![1308159.jpg](data:image/jpeg;base64,...)
